# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt

# %%
with open("/scratch/vdeltatt/imbalance-gain-causality/langevin/three_minima_with_z_4states_int/pickles_traj_intx/intvalue0.0_seed0_N2500_dt0.01_samplingdt1000_nsteps5000000_frict1_temp1.p","rb") as file:
    traj_intx = pickle.load(file)

print(traj_intx.shape)
# Out:
# (5000, 2500, 3)

# %%
traj0 = 1300
ntrajs = 100
samples = np.linspace(0,5000-1,200,dtype=int)

plt.figure(figsize=(7,5))
plt.plot(traj_intx[samples,traj0:traj0+ntrajs, 2], '-')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

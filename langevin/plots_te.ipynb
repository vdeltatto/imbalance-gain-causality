# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle
import scienceplots
plt.style.use(['science','notebook'])

# %% [markdown]
# ### Symmetric far wells along x, long time scales

# %%
N = 2500
k = 7
taus = np.arange(20,420,20,dtype=int)
alphas = np.linspace(0,1,300)
seeds = np.arange(20)

TEs_X_to_Y = np.zeros((len(seeds),len(taus)))
TEs_Y_to_X = np.zeros((len(seeds),len(taus)))
TEs_X_to_Y_discrete = np.zeros((len(seeds),len(taus)))
TEs_Y_to_X_discrete = np.zeros((len(seeds),len(taus)))

for iseed, seed in enumerate(seeds):
    _, TEs_X_to_Y[iseed], TEs_Y_to_X[iseed], TEs_X_to_Y_discrete[iseed], TEs_Y_to_X_discrete[iseed] = (
        pickle.load(open(f"./symmetric_energy_far/pickles_te/seed{seed}_N{N}_k{k}.p","rb"))
    )

# %%
# continuous
avg_X_to_Y, err_X_to_Y = TEs_X_to_Y.mean(axis=0), TEs_X_to_Y.mean(axis=0) / np.sqrt(TEs_X_to_Y.shape[0])
avg_Y_to_X, err_Y_to_X = TEs_Y_to_X.mean(axis=0), TEs_Y_to_X.mean(axis=0) / np.sqrt(TEs_Y_to_X.shape[0])

plt.plot(taus, avg_X_to_Y, 'o-', label="$X\\rightarrow Y$")
plt.plot(taus, avg_Y_to_X, 's-', label="$Y\\rightarrow X$")
plt.fill_between(taus, avg_X_to_Y-err_X_to_Y, avg_X_to_Y+err_X_to_Y, alpha=0.3)
plt.fill_between(taus, avg_Y_to_X-err_Y_to_X, avg_Y_to_X+err_Y_to_X, alpha=0.3)
plt.hlines(0.0, taus[0], taus[-1], linestyle="--", color="black")
plt.xlabel("$\\tau$")
plt.ylabel("Transfer Entropy")
plt.ylim([-0.01, 0.12])
plt.legend()
plt.show()

# discrete
avg_X_to_Y, err_X_to_Y = TEs_X_to_Y_discrete.mean(axis=0), TEs_X_to_Y_discrete.mean(axis=0) / np.sqrt(TEs_X_to_Y_discrete.shape[0])
avg_Y_to_X, err_Y_to_X = TEs_Y_to_X_discrete.mean(axis=0), TEs_Y_to_X_discrete.mean(axis=0) / np.sqrt(TEs_Y_to_X_discrete.shape[0])

plt.plot(taus, avg_X_to_Y, 'o-', label="$X\\rightarrow Y$")
plt.plot(taus, avg_Y_to_X, 's-', label="$Y\\rightarrow X$")
plt.fill_between(taus, avg_X_to_Y-err_X_to_Y, avg_X_to_Y+err_X_to_Y, alpha=0.3)
plt.fill_between(taus, avg_Y_to_X-err_Y_to_X, avg_Y_to_X+err_Y_to_X, alpha=0.3)
plt.hlines(0.0, taus[0], taus[-1], linestyle="--", color="black")
plt.xlabel("$\\tau$")
plt.ylabel("Transfer Entropy")
plt.ylim([-0.005, 0.095])
plt.legend()
plt.show()

# %% [markdown]
# ### Asymmetric far wells along x, long time scales

# %%
N = 2500
k = 7
taus = np.arange(20,420,20,dtype=int)
alphas = np.linspace(0,1,300)
seeds = np.arange(20)

TEs_X_to_Y = np.zeros((len(seeds),len(taus)))
TEs_Y_to_X = np.zeros((len(seeds),len(taus)))
TEs_X_to_Y_discrete = np.zeros((len(seeds),len(taus)))
TEs_Y_to_X_discrete = np.zeros((len(seeds),len(taus)))

for iseed, seed in enumerate(seeds):
    _, TEs_X_to_Y[iseed], TEs_Y_to_X[iseed], TEs_X_to_Y_discrete[iseed], TEs_Y_to_X_discrete[iseed] = (
        pickle.load(open(f"./asymmetric_energy_far/pickles_te/seed{seed}_N{N}_k{k}.p","rb"))
    )

# %%
# continuous
avg_X_to_Y, err_X_to_Y = TEs_X_to_Y.mean(axis=0), TEs_X_to_Y.mean(axis=0) / np.sqrt(TEs_X_to_Y.shape[0])
avg_Y_to_X, err_Y_to_X = TEs_Y_to_X.mean(axis=0), TEs_Y_to_X.mean(axis=0) / np.sqrt(TEs_Y_to_X.shape[0])

plt.plot(taus, avg_X_to_Y, 'o-', label="$X\\rightarrow Y$")
plt.plot(taus, avg_Y_to_X, 's-', label="$Y\\rightarrow X$")
plt.fill_between(taus, avg_X_to_Y-err_X_to_Y, avg_X_to_Y+err_X_to_Y, alpha=0.3)
plt.fill_between(taus, avg_Y_to_X-err_Y_to_X, avg_Y_to_X+err_Y_to_X, alpha=0.3)
plt.hlines(0.0, taus[0], taus[-1], linestyle="--", color="black")
plt.xlabel("$\\tau$")
plt.ylabel("Transfer Entropy")
plt.legend()
plt.ylim([-0.01, 0.12])
plt.show()

# discrete
avg_X_to_Y, err_X_to_Y = TEs_X_to_Y_discrete.mean(axis=0), TEs_X_to_Y_discrete.mean(axis=0) / np.sqrt(TEs_X_to_Y_discrete.shape[0])
avg_Y_to_X, err_Y_to_X = TEs_Y_to_X_discrete.mean(axis=0), TEs_Y_to_X_discrete.mean(axis=0) / np.sqrt(TEs_Y_to_X_discrete.shape[0])

plt.plot(taus, avg_X_to_Y, 'o-', label="$X\\rightarrow Y$")
plt.plot(taus, avg_Y_to_X, 's-', label="$Y\\rightarrow X$")
plt.fill_between(taus, avg_X_to_Y-err_X_to_Y, avg_X_to_Y+err_X_to_Y, alpha=0.3)
plt.fill_between(taus, avg_Y_to_X-err_Y_to_X, avg_Y_to_X+err_Y_to_X, alpha=0.3)
plt.hlines(0.0, taus[0], taus[-1], linestyle="--", color="black")
plt.xlabel("$\\tau$")
plt.ylabel("Transfer Entropy")
plt.ylim([-0.005, 0.095])
plt.legend()
plt.show()

# %% [markdown]
# ### Dagonal far wells, long time scales

# %%
N = 2500
k = 7
taus = np.arange(20,420,20,dtype=int)
alphas = np.linspace(0,1,300)
seeds = np.arange(20)

TEs_X_to_Y = np.zeros((len(seeds),len(taus)))
TEs_Y_to_X = np.zeros((len(seeds),len(taus)))
TEs_X_to_Y_discrete = np.zeros((len(seeds),len(taus)))
TEs_Y_to_X_discrete = np.zeros((len(seeds),len(taus)))

for iseed, seed in enumerate(seeds):
    _, TEs_X_to_Y[iseed], TEs_Y_to_X[iseed], TEs_X_to_Y_discrete[iseed], TEs_Y_to_X_discrete[iseed] = (
        pickle.load(open(f"./diagonal_wells_far/pickles_te/seed{seed}_N{N}_k{k}.p","rb"))
    )

# %%
# continuous
avg_X_to_Y, err_X_to_Y = TEs_X_to_Y.mean(axis=0), TEs_X_to_Y.mean(axis=0) / np.sqrt(TEs_X_to_Y.shape[0])
avg_Y_to_X, err_Y_to_X = TEs_Y_to_X.mean(axis=0), TEs_Y_to_X.mean(axis=0) / np.sqrt(TEs_Y_to_X.shape[0])

plt.plot(taus, avg_X_to_Y, 'o-', label="$X\\rightarrow Y$")
plt.plot(taus, avg_Y_to_X, 's-', label="$Y\\rightarrow X$")
plt.fill_between(taus, avg_X_to_Y-err_X_to_Y, avg_X_to_Y+err_X_to_Y, alpha=0.3)
plt.fill_between(taus, avg_Y_to_X-err_Y_to_X, avg_Y_to_X+err_Y_to_X, alpha=0.3)
plt.hlines(0.0, taus[0], taus[-1], linestyle="--", color="black")
plt.xlabel("$\\tau$")
plt.ylabel("Transfer Entropy")
plt.ylim([-0.01, 0.12])
plt.legend()
plt.show()

# discrete
avg_X_to_Y, err_X_to_Y = TEs_X_to_Y_discrete.mean(axis=0), TEs_X_to_Y_discrete.mean(axis=0) / np.sqrt(TEs_X_to_Y_discrete.shape[0])
avg_Y_to_X, err_Y_to_X = TEs_Y_to_X_discrete.mean(axis=0), TEs_Y_to_X_discrete.mean(axis=0) / np.sqrt(TEs_Y_to_X_discrete.shape[0])

plt.plot(taus, avg_X_to_Y, 'o-', label="$X\\rightarrow Y$")
plt.plot(taus, avg_Y_to_X, 's-', label="$Y\\rightarrow X$")
plt.fill_between(taus, avg_X_to_Y-err_X_to_Y, avg_X_to_Y+err_X_to_Y, alpha=0.3)
plt.fill_between(taus, avg_Y_to_X-err_Y_to_X, avg_Y_to_X+err_Y_to_X, alpha=0.3)
plt.hlines(0.0, taus[0], taus[-1], linestyle="--", color="black")
plt.xlabel("$\\tau$")
plt.ylabel("Transfer Entropy")
plt.ylim([-0.005, 0.095])
plt.legend()
plt.show()

# %% [markdown]
# ### Empirical free energy from simulations (small box, no projection, x:ref vs y:1st shell dipole angles)

# %%
k = 7
taus = np.arange(50,10000,50,dtype=int)
seeds = np.arange(1,21)

TEs_X_to_Y = np.zeros((len(seeds),len(taus)))
TEs_Y_to_X = np.zeros((len(seeds),len(taus)))
TEs_X_to_Y_discrete = np.zeros((len(seeds),len(taus)))
TEs_Y_to_X_discrete = np.zeros((len(seeds),len(taus)))

for iseed, seed in enumerate(seeds):
    _, TEs_X_to_Y[iseed], TEs_Y_to_X[iseed], TEs_X_to_Y_discrete[iseed], TEs_Y_to_X_discrete[iseed] = (
        pickle.load(open(f"./free_eng_ref_1st_noproj/pickles_te/seed{seed}_k{k}.p","rb"))
    )

# %%
# continuous
avg_X_to_Y, err_X_to_Y = TEs_X_to_Y.mean(axis=0), TEs_X_to_Y.mean(axis=0) / np.sqrt(TEs_X_to_Y.shape[0])
avg_Y_to_X, err_Y_to_X = TEs_Y_to_X.mean(axis=0), TEs_Y_to_X.mean(axis=0) / np.sqrt(TEs_Y_to_X.shape[0])

plt.plot(taus, avg_X_to_Y, 'o-', label="ref dipole $\\rightarrow $ 1st shell")
plt.plot(taus, avg_Y_to_X, 's-', label="1st shell $\\rightarrow $ ref dipole")
plt.fill_between(taus, avg_X_to_Y-err_X_to_Y, avg_X_to_Y+err_X_to_Y, alpha=0.3)
plt.fill_between(taus, avg_Y_to_X-err_Y_to_X, avg_Y_to_X+err_Y_to_X, alpha=0.3)
plt.hlines(0.0, taus[0], taus[-1], linestyle="--", color="black")
plt.xlabel("$\\tau$")
plt.ylabel("Transfer Entropy")
plt.xlim([-5, 2000])
plt.legend()
plt.show()

# discrete
avg_X_to_Y, err_X_to_Y = TEs_X_to_Y_discrete.mean(axis=0), TEs_X_to_Y_discrete.mean(axis=0) / np.sqrt(TEs_X_to_Y_discrete.shape[0])
avg_Y_to_X, err_Y_to_X = TEs_Y_to_X_discrete.mean(axis=0), TEs_Y_to_X_discrete.mean(axis=0) / np.sqrt(TEs_Y_to_X_discrete.shape[0])

plt.plot(taus, avg_X_to_Y, 'o-', label="$X\\rightarrow Y$")
plt.plot(taus, avg_Y_to_X, 's-', label="$Y\\rightarrow X$")
plt.fill_between(taus, avg_X_to_Y-err_X_to_Y, avg_X_to_Y+err_X_to_Y, alpha=0.3)
plt.fill_between(taus, avg_Y_to_X-err_Y_to_X, avg_Y_to_X+err_Y_to_X, alpha=0.3)
plt.hlines(0.0, taus[0], taus[-1], linestyle="--", color="black")
plt.xlabel("$\\tau$")
plt.ylabel("Transfer Entropy")
#plt.ylim([-0.005, 0.095])
plt.xlim([-5, 2000])
plt.legend()
plt.show()

# %% [markdown]
# ### Empirical free energy from simulations (small box, no projection, x:ref vs y:1st shell dipole angles, ASYMMETRIC AUTOCORRS)

# %%
k = 7
taus = np.arange(50,5000,50,dtype=int)
seeds = np.arange(1,21)

TEs_X_to_Y = np.zeros((len(seeds),len(taus)))
TEs_Y_to_X = np.zeros((len(seeds),len(taus)))
TEs_X_to_Y_discrete = np.zeros((len(seeds),len(taus)))
TEs_Y_to_X_discrete = np.zeros((len(seeds),len(taus)))

for iseed, seed in enumerate(seeds):
    _, TEs_X_to_Y[iseed], TEs_Y_to_X[iseed] = (
        pickle.load(open(f"./free_eng_ref_1st_noproj_asymmetric_autocorr/pickles_te/seed{seed}_k{k}.p","rb"))
    )

# %%
avg_X_to_Y, err_X_to_Y = TEs_X_to_Y.mean(axis=0), TEs_X_to_Y.mean(axis=0) / np.sqrt(TEs_X_to_Y.shape[0])
avg_Y_to_X, err_Y_to_X = TEs_Y_to_X.mean(axis=0), TEs_Y_to_X.mean(axis=0) / np.sqrt(TEs_Y_to_X.shape[0])

# NB labels exchanged because in trajectories X is faster than Y, but in simulations ref dipole angle (X)
# actually is slower than 1st shell dipole angle (Y)
plt.plot(taus, avg_Y_to_X, 's-', label="X $\\rightarrow Y$") # X: ref dipole, Y: 1st shell
plt.plot(taus, avg_X_to_Y, 'o-', label="$Y\\rightarrow X$")
plt.fill_between(taus, avg_Y_to_X-err_Y_to_X, avg_Y_to_X+err_Y_to_X, alpha=0.3)
plt.fill_between(taus, avg_X_to_Y-err_X_to_Y, avg_X_to_Y+err_X_to_Y, alpha=0.3)
plt.hlines(0.0, taus[0], taus[-1], linestyle="--", color="black")
plt.xlabel("$\\tau$")
plt.ylabel("Transfer Entropy")
plt.xlim([-5, 2000])
plt.legend()
plt.show()

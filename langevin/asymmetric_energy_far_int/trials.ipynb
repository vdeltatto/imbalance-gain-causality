# %%
import numpy as np
import pickle

# %%
with open("/scratch/vdeltatt/imbalance-gain-causality/langevin/asymmetric_energy_far_int/pickles_traj/seed0_N2500_dt0.01_samplingdt1000_nsteps1000000_frict1_temp1.p","rb") as file:
    traj = pickle.load(file)
print(traj.shape)
# Out:
# (1000, 2500, 2)
